# %%
#Creating environment and importing necessory libraries
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# reading dataset and describing the dataset

women_degrees = pd.read_csv('percent-bachelors-degrees-women-usa.csv')
women_degrees.head()
# Out:
#    Year  Agriculture  Architecture  Art and Performance    Biology   Business  \
# 0  1970     4.229798     11.921005                 59.7  29.088363   9.064439
# 1  1971     5.452797     12.003106                 59.9  29.394403   9.503187
# 2  1972     7.420710     13.214594                 60.4  29.810221  10.558962
# 3  1973     9.653602     14.791613                 60.2  31.147915  12.804602
# 4  1974    14.074623     17.444688                 61.9  32.996183  16.204850
#
#    Communications and Journalism  Computer Science  Education  Engineering  \
# 0                           35.3              13.6  74.535328          0.8
# 1                           35.5              13.6  74.149204          1.0
# 2                           36.6              14.9  73.554520          1.2
# 3                           38.4              16.4  73.501814          1.6
# 4                           40.5              18.9  73.336811          2.2
#
# ...

# %%
#basic stat using pandas' describe
women_degrees.describe()
# Out:
#               Year  Agriculture  Architecture  Art and Performance    Biology  \
# count    42.000000    42.000000     42.000000            42.000000  42.000000
# mean   1990.500000    33.848165     33.685540            61.100000  49.429864
# std      12.267844    12.552731      9.574057             1.305336  10.087725
# min    1970.000000     4.229798     11.921005            58.600000  29.088363
# 25%    1980.250000    30.840814     28.520709            60.200000  44.311821
# 50%    1990.500000    33.317552     35.994852            61.300000  50.971469
# 75%    2000.750000    45.663953     40.790605            62.000000  58.679194
# max    2011.000000    50.037182     44.499331            63.400000  62.169456
#
#         Business  Communications and Journalism  Computer Science  Education  \
# count  42.000000                      42.000000         42.000000  42.000000
# mean   40.653471                      56.216667         25.809524  76.356236
# ...

# %%
# Generating a line chart that visualizes the
# historical percentage of Biology degrees awarded to women:

plt.plot(women_degrees['Year'],women_degrees['Biology'])
plt.xlabel('Women Degrees')
plt.ylabel('Biology')
plt.title('Biology degrees awarded to women')
plt.show()

# %% [markdown]
# #### From the plot, we can tell that Biology degrees increased steadily from 1970 and peaked in the early 2000's. We can also tell that the percentage has stayed above 50% since around 1987.
# #### While it's helpful to visualize the trend of Biology degrees awarded to women, it only tells half the story. If we want the gender gap to be apparent and emphasized in the plot, we need a visual analogy to the difference in the percentages between the genders.

# %%
#calculating number of degrees awarded to men in Biology
Biology_degrees_Awarded_to_men = 100 - women_degrees['Biology']

# %%
Men_degrees = 100 - women_degrees['Biology']
plt.plot(women_degrees['Year'],women_degrees['Biology'],c='blue', label ='Women')
plt.plot(women_degrees['Year'],Men_degrees,c='green', label='Men')

plt.xlabel("Gender")
plt.ylabel('Year')
plt.title('Percentage of Biology Degrees Awarded By Gender')
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# #### The chart containing both line charts tells a more complete story than the one containing just the line chart that visualized just the women percentages. This plot instead tells the story of two distinct periods. In the first period, from 1970 to around 1987, women were a minority when it came to majoring in Biology while in the second period, from around 1987 to around 2012, women became a majority. You can see the point where women overtook men where the lines intersect.

# %%
# Let's generate line charts for four STEM degree categories on a grid 

major_cats = ['Biology', 'Computer Science', 'Engineering', 'Math and Statistics']
fig = plt.figure(figsize=(12, 12))

for sp in range(0,4):
    ax = fig.add_subplot(2,2,sp+1)
    ax.tick_params(bottom='off',top='off',left='off',right='off')
    ax.spines["right"].set_visible(False)
    ax.spines["left"].set_visible(False)
    ax.spines["bottom"].set_visible(False)
    ax.spines["top"].set_visible(False)
    ax.plot(women_degrees['Year'], women_degrees[major_cats[sp]], c='blue', label='Women')
    ax.plot(women_degrees['Year'], 100-women_degrees[major_cats[sp]], c='green', label='Men')
    # Add your code here.
    ax.set_xlim(1968,2011)
    ax.set_ylim(0,100)
    ax.set_title(major_cats[sp])
# Calling pyplot.legend() here will add the legend to the last subplot that was created.
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# #### we can conclude that the gender gap in Computer Science and Engineering have big gender gaps while the gap in Biology and Math and Statistics is quite small. In addition, the first two degree categories are dominated by men while the latter degree categories are much more balanced.

# %%
fig = plt.figure(figsize=(18, 3))
stem_cats = ['Psychology', 'Biology', 'Math and Statistics', 'Physical Sciences', 'Computer Science', 'Engineering']

for sp in range(0,6):
    ax = fig.add_subplot(1,6,sp+1)
    ax.plot(women_degrees['Year'], women_degrees[stem_cats[sp]], c='blue', label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[stem_cats[sp]], c='green', label='Men', linewidth=3)
    for key,spine in ax.spines.items():
        spine.set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(stem_cats[sp])
    ax.tick_params(bottom="off", top="off", left="off", right="off")
    if sp==0:
        ax.text(2005,87,'Men')
        ax.text(2002,8,'Women')
    if sp==5:
        ax.text(2005,62,'Men')
        ax.text(2001,35,'Women')
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# #### The plots are from largest to smallest ending gender gaps
# #### The leftmost plot has the largest gender gap in 1968 while the rightmost plot has the smallest gender gap in 1968.

# %%
# Comparing across all degree categories

stem_cats = ['Psychology', 'Biology', 'Math and Statistics', 'Physical Sciences', 'Computer Science', 'Engineering']
lib_arts_cats = ['Foreign Languages', 'English', 'Communications and Journalism', 'Art and Performance', 'Social Sciences and History']
other_cats = ['Health Professions', 'Public Administration', 'Education', 'Agriculture','Business', 'Architecture']

# %%
fig = plt.figure(figsize=(16,20))

stem_cats = ['Psychology', 'Biology', 'Math and Statistics', 'Physical Sciences', 'Computer Science', 'Engineering']
lib_arts_cats = ['Foreign Languages', 'English', 'Communications and Journalism', 'Art and Performance', 'Social Sciences and History']
other_cats = ['Health Professions', 'Public Administration', 'Education', 'Agriculture','Business', 'Architecture']

ploting = [1,4,7,10,13,16,2,5,8,11,14,17,3,6,9,12,15,18]
count = 0
for sp in range(0,6):
    ax = fig.add_subplot(6,3,ploting[count])
    ax.plot(women_degrees['Year'], women_degrees[stem_cats[sp]], c='blue', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[stem_cats[sp]], c='green', linewidth=3)
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    #ax.set_ylim(0,100)
    ax.set_yticks([0,100])
    ax.set_title(stem_cats[sp])
    ax.axhline(50, c=(171/255, 171/255, 171/255), alpha=0.3)
    
    ax.tick_params(bottom="off", top="off", left="off", right="off",labelbottom='off')
    count += 1
    if  sp == 0:
        ax.text(2005, 87, 'Women')
        ax.text(2052, 8, 'Men')
    if sp == 5:
        ax.text(2005, 90, 'Men')
        ax.text(2005, 9, 'Women')
ax.tick_params(labelbottom='on')
for i in range(0,5):
    ax = fig.add_subplot(6,3,ploting[count])
    ax.plot(women_degrees['Year'],women_degrees[lib_arts_cats[i]], c = 'blue',linewidth=3)
    ax.plot(women_degrees['Year'],100-women_degrees[lib_arts_cats[i]], c = 'green',linewidth=3)
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    #ax.set_ylim(0,100)
    ax.set_yticks([0,100])
    ax.set_title(lib_arts_cats[i])
    ax.tick_params(bottom="off", top="off", left="off", right="off",labelbottom='off')    
    ax.axhline(50, c=(171/255, 171/255, 171/255), alpha=0.3)
    if i == 0:
        ax.text(2005,80,'Women')
        ax.text(2005,20,'Men')
    count += 1
count += 1
ax.tick_params(labelbottom='on')
for i in range(0,6):
    ax = fig.add_subplot(6,3,ploting[count])
    ax.plot(women_degrees['Year'],women_degrees[other_cats[i]], c = 'blue',linewidth=3)
    ax.plot(women_degrees['Year'],100-women_degrees[other_cats[i]], c = 'green',linewidth=3)
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    #ax.set_ylim(0,100)
    ax.set_yticks([0,100])
    ax.set_title(other_cats[i])
    ax.tick_params(bottom="off", top="off", left="off", right="off",labelbottom='off')
    ax.axhline(50, c=(171/255, 171/255, 171/255), alpha=0.3)
    if i == 0:
        ax.text(2005,90,'Women')
        ax.text(2005,6,'Men')
    if i == 5:
        ax.text(2005,65,'Women')
        ax.text(2005,30,'Men')
    count += 1
ax.tick_params(labelbottom='on')
fig.savefig("gender_gaps.png")

# %% [markdown]
# ### From the above plot  we can clearly see the gender gaps in distribution of degrees in various fields.
